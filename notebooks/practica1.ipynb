# %%
import numpy as np

# %% [markdown]
# como definir escalares, vector, matriz, y escalares y ver sus magnitudes

# %%
escalar = 5.78
vector = np.array([1,2,3,4,5,6])
matriz = np.array([1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]
tensor = ([
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
    [[1,2,3,4,5,6],[1,2,3,4,5,6],[1,2,3,4,5,6]]
])
